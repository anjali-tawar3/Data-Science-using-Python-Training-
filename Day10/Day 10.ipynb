# %%
#spilt

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = plt.imread(r"C:\Users\Anjali\Downloads\CAT.jpeg")

# %%
cat_arr=arr.copy()


plt.imshow(cat_arr)

# %%
cat_arr.shape
# Out:
# (1080, 1920, 3)

# %%
a=np.random.randint(0,255,(3,3,3))
plt.imshow(a)

# %%
while True:#including 0 and False the code will run!!  it can be . true,1,5,iitm the condition should be true
    a=np.random.randint(0,255,(3,3,3))
    plt.imshow(a)
    plt.show()
    display(clear = True) # it clears the previous result
# Out:
# KeyboardInterrupt

# %%
a=np.random.randint(0,255,(4,4,3))
a
# Out:
# array([[[ 12, 182, 133],
#         [ 90, 221, 154],
#         [156, 187, 124],
#         [ 53,  41,  92]],
#
#        [[  9, 139, 226],
#         [  8, 153, 213],
#         [150,  18,  52],
#         [ 60, 208, 157]],
#
#        [[ 22, 172, 192],
#         [ 22, 254, 216],
#         [193, 240,   3],
#         [  3,  86,  75]],
#
#        [[232, 132, 243],
#         [ 41,   8, 189],
#         [251, 245, 173],
#         [100, 121,  54]]], dtype=int32)

# %%
final_arr=np.split(a,4,axis=1)
len(final_arr)
# Out:
# 4

# %%
plt.imshow(a)

# %%
plt.imshow(final_arr[0])

# %%
plt.imshow(final_arr[1])

# %%
plt.imshow(final_arr[2])

# %%
plt.imshow(final_arr[3])

# %%
arr_3_part= np.split(a,3,axis=2)

# %%
plt.imshow(a)

# %%
len(arr_3_part)
# Out:
# 3

# %%
plt.imshow(arr_3_part[0])

# %%
plt.imshow(cat_arr)

# %%
plt.imshow(np.split(cat_arr,3,axis=2)[2])

# %%
plt.imshow(np.split(cat_arr,2,axis=1)[0])

# %%
plt.imshow(np.split(cat_arr,2,axis=1)[1])

# %%
plt.imshow(np.split(cat_arr,2,axis=0)[0])

# %%
plt.imshow(np.split(cat_arr,2,axis=0)[1])

# %%
cat_arr.shape
# Out:
# (1080, 1920, 3)

# %%
1920/3
# Out:
# 640.0

# %%
plt.imshow(cat_arr[:,:640,:])

# %%
plt.imshow(cat_arr[:,640:640*2,:])

# %%
plt.imshow(cat_arr[:,640*2:,:])

# %%
#where: condition, iftrue(condition, iffalsecondition
#clip : outliers remove/replace
#broadcasting

# %%
a= np.random.randint(1,500,(4,4))
a
# Out:
# array([[ 56, 353, 179, 178],
#        [201,  30, 210, 388],
#        [214, 249, 279, 448],
#        [ 30, 447, 484, 174]], dtype=int32)

# %%
np.where(a>200)
# Out:
# (array([0, 1, 1, 1, 2, 2, 2, 2, 3, 3]), array([1, 0, 2, 3, 0, 1, 2, 3, 1, 2]))

# %%
np.where(a>200,'high sales','low sales')
# Out:
# array([['low sales', 'high sales', 'low sales', 'low sales'],
#        ['high sales', 'low sales', 'high sales', 'high sales'],
#        ['high sales', 'high sales', 'high sales', 'high sales'],
#        ['low sales', 'high sales', 'high sales', 'low sales']],
#       dtype='<U10')

# %%
np.where(a>200,'high sales',a)
# Out:
# array([['56', 'high sales', '179', '178'],
#        ['high sales', '30', 'high sales', 'high sales'],
#        ['high sales', 'high sales', 'high sales', 'high sales'],
#        ['30', 'high sales', 'high sales', '174']], dtype='<U11')

# %%
a
# Out:
# array([[ 56, 353, 179, 178],
#        [201,  30, 210, 388],
#        [214, 249, 279, 448],
#        [ 30, 447, 484, 174]], dtype=int32)

# %%
np.clip(a,100,250) # padding in lower limit and upper limit
# Out:
# array([[100, 250, 179, 178],
#        [201, 100, 210, 250],
#        [214, 249, 250, 250],
#        [100, 250, 250, 174]], dtype=int32)

# %%
#(very important based on interview) broadcasting :

# %%
a=np.random.randint(1,10,7)
b=np.random.randint(1,10,(7,7))
print(a,'\n')
print(b)
# Out:
# [9 4 3 2 2 4 2]
#
# [[8 4 5 7 6 4 9]
#  [8 3 6 9 6 5 2]
#  [6 2 6 2 7 3 5]
#  [3 8 5 8 9 9 8]
#  [3 6 4 7 8 1 8]
#  [3 5 6 3 8 9 3]
#  [1 2 8 1 6 4 8]]

# %%
a+b
# Out:
# array([[17,  8,  8,  9,  8,  8, 11],
#        [17,  7,  9, 11,  8,  9,  4],
#        [15,  6,  9,  4,  9,  7,  7],
#        [12, 12,  8, 10, 11, 13, 10],
#        [12, 10,  7,  9, 10,  5, 10],
#        [12,  9,  9,  5, 10, 13,  5],
#        [10,  6, 11,  3,  8,  8, 10]], dtype=int32)

# %%
a=np.random.randint(1,10,7)
b=np.random.randint(1,10,(2,7))
print(a,'\n')
print(b)
# Out:
# [7 3 6 3 6 1 6]
#
# [[1 4 7 1 9 4 9]
#  [5 5 7 5 3 5 3]]

# %%
a+b
# Out:
# array([[ 8,  7, 13,  4, 15,  5, 15],
#        [12,  8, 13,  8,  9,  6,  9]], dtype=int32)

# %%
a=np.random.randint(1,10,7)
b=np.random.randint(1,10,(1,7))
print(a,'\n')
print(b)
# Out:
# [7 1 3 3 4 8 1]
#
# [[3 1 6 5 1 8 6]]

# %%
a+b
# Out:
# array([[10,  2,  9,  8,  5, 16,  7]], dtype=int32)

# %%
a=np.random.randint(1,10,(7,1))
b=np.random.randint(1,10,(1,7))
print(a,'\n')
print(b)
# Out:
# [[5]
#  [4]
#  [5]
#  [4]
#  [1]
#  [7]
#  [7]]
#
# [[6 4 9 8 1 6 4]]

# %%
a+b
# Out:
# array([[11,  9, 14, 13,  6, 11,  9],
#        [10,  8, 13, 12,  5, 10,  8],
#        [11,  9, 14, 13,  6, 11,  9],
#        [10,  8, 13, 12,  5, 10,  8],
#        [ 7,  5, 10,  9,  2,  7,  5],
#        [13, 11, 16, 15,  8, 13, 11],
#        [13, 11, 16, 15,  8, 13, 11]], dtype=int32)

# %%
a=np.random.randint(1,10,(7,1))
b=np.random.randint(1,10,(5,7))
print(a,'\n')
print(b)
# Out:
# [[5]
#  [8]
#  [2]
#  [6]
#  [7]
#  [1]
#  [7]]
#
# [[4 1 1 7 6 2 3]
#  [5 9 3 1 8 5 8]
#  [3 6 5 4 1 6 3]
#  [2 3 5 1 8 4 9]
#  [3 8 1 6 7 5 9]]

# %%
a+b #it will throw an error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 a+b
#
# ValueError: operands could not be broadcast together with shapes (7,1) (5,7)

# %%
a=np.random.randint(1,10,(1,1))
b=np.random.randint(1,10,(5,7))
print(a,'\n')
print(b)
# Out:
# [[5]]
#
# [[1 7 9 5 5 9 3]
#  [2 5 1 1 5 7 3]
#  [1 3 2 1 9 8 5]
#  [8 2 2 2 4 6 7]
#  [9 7 1 1 9 8 8]]

# %%
a+b
# Out:
# array([[ 6, 12, 14, 10, 10, 14,  8],
#        [ 7, 10,  6,  6, 10, 12,  8],
#        [ 6,  8,  7,  6, 14, 13, 10],
#        [13,  7,  7,  7,  9, 11, 12],
#        [14, 12,  6,  6, 14, 13, 13]], dtype=int32)

# %%
a=np.random.randint(1,10,(1,1,5))
b=np.random.randint(1,10,(5,5,5))
print(a,'\n')
print(b)
# Out:
# [[[2 2 1 3 6]]]
#
# [[[4 9 7 2 1]
#   [6 7 5 4 9]
#   [8 3 9 9 9]
#   [1 5 9 1 3]
#   [1 1 8 5 1]]
#
#  [[5 1 1 2 7]
#   [2 4 1 3 1]
#   [4 1 6 3 7]
#   [3 9 3 1 5]
#   [5 7 3 3 2]]
#
#  [[7 9 9 2 5]
#   [4 2 6 1 1]
#   [1 6 8 5 6]
#   [5 9 6 6 9]
#   [6 6 4 6 6]]
#
#  [[1 3 6 9 2]
#   [1 7 5 1 8]
#   [1 8 5 3 4]
#   [9 3 9 5 6]
#   [9 1 6 6 5]]
#
#  [[9 3 1 1 6]
#   [2 4 9 4 5]
#   [2 3 1 5 2]
#   [4 1 5 8 8]
#   [5 7 1 7 1]]]

# %%
a+b
# Out:
# array([[[ 6, 11,  8,  5,  7],
#         [ 8,  9,  6,  7, 15],
#         [10,  5, 10, 12, 15],
#         [ 3,  7, 10,  4,  9],
#         [ 3,  3,  9,  8,  7]],
#
#        [[ 7,  3,  2,  5, 13],
#         [ 4,  6,  2,  6,  7],
#         [ 6,  3,  7,  6, 13],
#         [ 5, 11,  4,  4, 11],
#         [ 7,  9,  4,  6,  8]],
#
#        [[ 9, 11, 10,  5, 11],
#         [ 6,  4,  7,  4,  7],
#         [ 3,  8,  9,  8, 12],
#         [ 7, 11,  7,  9, 15],
#         [ 8,  8,  5,  9, 12]],
#
#        [[ 3,  5,  7, 12,  8],
#         [ 3,  9,  6,  4, 14],
#         [ 3, 10,  6,  6, 10],
#         [11,  5, 10,  8, 12],
#         [11,  3,  7,  9, 11]],
#
#        [[11,  5,  2,  4, 12],
#         [ 4,  6, 10,  7, 11],
#         [ 4,  5,  2,  8,  8],
#         [ 6,  3,  6, 11, 14],
#         [ 7,  9,  2, 10,  7]]], dtype=int32)

# %% [markdown]
# # PANDAS

# %%
# Data science
# Data: Explore(Exploratory data Analysis)
# EDA

# %%
#Anupam: lives in nainital
#Piyush: 100
#explore
#Excel,SQL,PowerBI,Python: EDA

# %%
# PYTHON : Programming language
# pandas: File Handling()
# pandas: table
#data type in pandas: dataframe(int, object, date) and series

# %%
#dataframe= df

# %%
# Data Explore= Report(insights): useful info for the company to take decisions 
# Report>>> Data Scientist

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %%
import random
products=['chair','tables','laptop','phones','charger']
region=['east','west','north','south']
all_date=pd.date_range('01-01-2025','23-07-2025')

# %%
data={'Order_ID':range(1,1001),
      'Date':random.choices(all_date,k=1000),
      'Region Name': random.choices(region,k=1000),
      'Product Name':random.choices(products,k=1000),
      'Sales':np.random.randint(100,10000,1000),
      'Qty':np.random.randint(100,10000,1000),
      'Profit':np.random.randint(-10000,10000,1000)
     }
table=pd.DataFrame(data)
table
# Out:
#      Order_ID       Date Region Name Product Name  Sales   Qty  Profit
# 0           1 2025-03-14        west        chair   7867  5225   -7284
# 1           2 2025-03-31       south       tables   3852  5629   -3249
# 2           3 2025-02-18       north       phones   1179  8846    7667
# 3           4 2025-07-08       north       phones   8170  5619    8089
# 4           5 2025-03-02       north       phones   5660  6672    5528
# ..        ...        ...         ...          ...    ...   ...     ...
# 995       996 2025-02-03        west       phones   6663   131    8787
# 996       997 2025-04-16        east       phones   9531  7018    9129
# 997       998 2025-07-15       south       phones   5581  8246    9500
# 998       999 2025-04-21       south      charger   1891  3011    1179
# 999      1000 2025-04-27       north       phones   1359  8007   -1770
#
# [1000 rows x 7 columns]

# %%
#top data
table.head() # top 5 data is printed
# Out:
#    Order_ID       Date Region Name Product Name  Sales   Qty  Profit
# 0         1 2025-03-14        west        chair   7867  5225   -7284
# 1         2 2025-03-31       south       tables   3852  5629   -3249
# 2         3 2025-02-18       north       phones   1179  8846    7667
# 3         4 2025-07-08       north       phones   8170  5619    8089
# 4         5 2025-03-02       north       phones   5660  6672    5528

# %%
table.head(10)
# Out:
#    Order_ID       Date Region Name Product Name  Sales   Qty  Profit
# 0         1 2025-03-14        west        chair   7867  5225   -7284
# 1         2 2025-03-31       south       tables   3852  5629   -3249
# 2         3 2025-02-18       north       phones   1179  8846    7667
# 3         4 2025-07-08       north       phones   8170  5619    8089
# 4         5 2025-03-02       north       phones   5660  6672    5528
# 5         6 2025-04-06       south        chair   8677   673    2090
# 6         7 2025-05-05        east       tables   7920  3141   -5294
# 7         8 2025-03-04       north      charger   4655  3135   -1900
# 8         9 2025-03-13        east       tables   9669  3522   -9676
# 9        10 2025-05-20        west       phones   8146  6408   -9616

# %%
#bottom data
table.tail() #bottom 5 data is printed
# Out:
#      Order_ID       Date Region Name Product Name  Sales   Qty  Profit
# 995       996 2025-02-03        west       phones   6663   131    8787
# 996       997 2025-04-16        east       phones   9531  7018    9129
# 997       998 2025-07-15       south       phones   5581  8246    9500
# 998       999 2025-04-21       south      charger   1891  3011    1179
# 999      1000 2025-04-27       north       phones   1359  8007   -1770

# %%
table.sample() #random data from the table is printed
# Out:
#      Order_ID       Date Region Name Product Name  Sales   Qty  Profit
# 870       871 2025-03-16        west       phones   5758  1863    -927

# %%
table.sample(10)
# Out:
#      Order_ID       Date Region Name Product Name  Sales   Qty  Profit
# 176       177 2025-03-23       north       laptop   2561  9391   -4523
# 429       430 2025-03-21        east       laptop   1068  6144    -277
# 73         74 2025-03-07        west       tables   8341  6108   -2613
# 428       429 2025-04-07        west       tables   5873  4945    3152
# 214       215 2025-06-25        west      charger    821  1471    1725
# 328       329 2025-02-07        east       laptop   6400  8440   -7694
# 427       428 2025-01-13       north       phones    301  3748   -1358
# 384       385 2025-03-31       north        chair   4399  7633   -4156
# 206       207 2025-04-11       south       laptop   2373  2208    8197
# 59         60 2025-03-18       north       laptop   2935  9179     -29

# %%
# information: about data
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      1000 non-null   int64
#  1   Date          1000 non-null   datetime64[ns]
#  2   Region Name   1000 non-null   object
#  3   Product Name  1000 non-null   object
#  4   Sales         1000 non-null   int32
#  5   Qty           1000 non-null   int32
#  6   Profit        1000 non-null   int32
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 43.1+ KB

# %%
#int64= int 64 bytes(maximun data storage)

# %%
#columns name
table.columns
# Out:
# Index(['Order_ID', 'Date', 'Region Name', 'Product Name', 'Sales', 'Qty',
#        'Profit'],
#       dtype='object')

# %%
#index
table.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# to check nan values
table.isna()
#table.isnull()
# Out:
#      Order_ID   Date  Region Name  Product Name  Sales    Qty  Profit
# 0       False  False        False         False  False  False   False
# 1       False  False        False         False  False  False   False
# 2       False  False        False         False  False  False   False
# 3       False  False        False         False  False  False   False
# 4       False  False        False         False  False  False   False
# ..        ...    ...          ...           ...    ...    ...     ...
# 995     False  False        False         False  False  False   False
# 996     False  False        False         False  False  False   False
# 997     False  False        False         False  False  False   False
# 998     False  False        False         False  False  False   False
# 999     False  False        False         False  False  False   False
#
# [1000 rows x 7 columns]

# %%
table.isna().value_counts()
# Out:
# Order_ID  Date   Region Name  Product Name  Sales  Qty    Profit
# False     False  False        False         False  False  False     1000
# Name: count, dtype: int64
