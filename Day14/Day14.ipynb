# %%
# Seaborn Complete

# %%
import seaborn as sns
print('done')
# Out:
# done

# %%
#advance charts create
#matplotlib:- help(functions: Seaborn)
#plotly: python dashborad(): dash module

#seaborn: Doc:

# %%
# seaborn all datasets
print(sns.get_dataset_names())
print(len(sns.get_dataset_names()))
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
# 22

# %%
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# internet required
df_titanic = sns.load_dataset('titanic')
df_titanic.sample()
# Out:
#      survived  pclass   sex  age  sibsp  parch    fare embarked  class  who  \
# 650         0       3  male  NaN      0      0  7.8958        S  Third  man
#
#      adult_male deck  embark_town alive  alone
# 650        True  NaN  Southampton    no   True

# %%
# sns.countplot
# sns.barplot
# sns.boxplot
# sns.scatterplot
# sns.catplot
# sns.pairplot
# sns.heatmap
# sns.regplot
# sns.lmplot
# sns.lineplot
# sns.kdeplot
# sns.violinplot
#sns.relplot
#sns.histplot
#sns.displot

# %%
import matplotlib.pyplot as plt
sns.countplot(data= df_titanic, x='sex') # hue: further divide: bases on categorical data
plt.show()

# %%
# sns.countplot
sns.countplot(data= df_titanic, x='sex', hue= 'alive', palette= sns.color_palette('mako',2)) # hue: further divide: bases on categorical data
plt.title('Titanic Survival Analysis(Based on Sex)')
plt.show()

# %%
# juilius Ai

# %%
# sns.barplot
sns.barplot(data=df_titanic, x='class', y='fare', hue='alive',palette= sns.color_palette('mako',2)) #estimator by default show mean
plt.title('Titanic Fare Prized Analysis(Based on Class)')
# Out:
# Text(0.5, 1.0, 'Titanic Fare Prized Analysis(Based on Class)')

# %%
# confidence interval (CI) : by default 95%
sns.barplot(data=df_titanic, x='class', y='fare', hue='alive',palette= sns.color_palette('mako',2),errorbar=('ci',0)) # errorbar refers to the CI value
plt.grid(color= 'r',alpha= 0.1)
plt.title('Titanic Fare Prized Analysis(Based on Class)')
# Out:
# Text(0.5, 1.0, 'Titanic Fare Prized Analysis(Based on Class)')

# %%
# MOST IMPORTANT PLOT IN SEABORN
# sns.boxplot : to detect outliers and check data distribution
# to detect outliers:
# range : min to max(19-22) :35,28,45(outliers : fliers)
# Q2: Quantile: 50%
# Q1: Quantile: 25%
# Q3: Quantile: 75%
# IQR: Q3-Q1
# emperical rule:
# UW(upper whiskers)= Q3 + 1.5 * IQR
# LW(lower whiskers)= Q1 - 1.5 * IQR

# %%
sns.boxplot(data=df_titanic,x='class', y='fare', hue='sex',palette= sns.color_palette('mako',2))
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
plt.figure(figsize=(7,7))
sns.boxplot(data=df_titanic,y='class', x='fare', hue='sex',palette= sns.color_palette('mako',2),orient='h')
# Out:
# <Axes: xlabel='fare', ylabel='class'>

# %%
# sns.violinplot
sns.violinplot(data= df_titanic,x='class',y='fare', hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
df_pen=sns.load_dataset('penguins')
df_pen
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# sns.violinplot
sns.violinplot(data= df_pen,x='species',y='body_mass_g', hue='sex')
# the more it is spread the more data there is 
# violinplot contains boxplot inside it
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# sns.scatterplot
# numerical vs numerical analysis
sns.scatterplot(data= df_pen, x='bill_length_mm', y='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# desicion making is faster 
sns.scatterplot(data= df_pen, x='bill_length_mm', y='bill_depth_mm', hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
#regplot:to show regression graph
# nagative co-relation  and positive co-relation
sns.regplot(data= df_pen, x='bill_length_mm', y='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
df_tips=sns.load_dataset('tips')

# %%
df_tips.sample()
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 9       14.78  3.23  Male     No  Sun  Dinner     2

# %%
#catplot: multi-dimensional data
sns.catplot(data = df_tips, x='time', y='total_bill',kind='bar',hue='sex') #kind= strip

# %%
sns.catplot(data = df_tips, x='time', y='total_bill',kind='bar',hue='sex',row='smoker',col='day')

# %%
sns.catplot(data = df_tips, x='time', y='total_bill',kind='bar',hue='sex',row='smoker',col='day',palette= sns.color_palette('mako',2))

# %%
sns.catplot(data = df_tips, x='time', y='total_bill',kind='violin',hue='sex',row='smoker',col='day',palette= sns.color_palette('mako',2))

# %%
# scatter plot not allowed in catplot
# sns.catplot(data = df_tips, x='total_bill', y='tip',kind='scatter',hue='sex',row='smoker',col='day',palette= sns.color_palette('mako',2))

# %%
#sns.implot
sns.lmplot(data = df_tips, x='total_bill', y='tip',row='smoker',col='day',palette= sns.color_palette('mako',2))

# %%
#sns.regplot
sns.relplot(data = df_tips, x='total_bill', y='tip',kind='scatter',hue='sex',row='smoker',col='day',palette= sns.color_palette('mako',2))

# %%
# sns.lineplot
sns.load_dataset('flights')
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df_flight=sns.load_dataset('flights')
df_flight.sample()
# Out:
#      year month  passengers
# 116  1958   Sep         404

# %%
df_flight.head(10)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# 5  1949   Jun         135
# 6  1949   Jul         148
# 7  1949   Aug         148
# 8  1949   Sep         136
# 9  1949   Oct         119

# %%
sns.lineplot(data=df_flight, x='year',y='passengers',hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=df_flight, x='year',y='passengers',hue='month',linestyle='--')
plt.grid()

# %%
#sns.pairplot (numerical vs numerical)
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris=sns.load_dataset('iris')
df_iris.sample()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 44           5.1          3.8           1.9          0.4  setosa

# %%
df_iris.iloc[:,:-1]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df_iris.iloc[:,:-1].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
# corr() - 
# >0: +ve : +ve correlation
# <0: -ve : -ve correlation
# =0 : no correlation

# %%
sns.pairplot(data=df_iris)

# %%
sns.pairplot(data=df_iris,hue='species')

# %%
sns.pairplot(data=df_iris,hue='species',corner= True)

# %%
#sns.kdeplot : Kernel Density Estimation
sns.kdeplot(data = df_iris, x = 'sepal_length', y = 'petal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.kdeplot(data = df_iris, x = 'sepal_length', y = 'petal_width', hue='species')
sns.scatterplot(data = df_iris, x = 'sepal_length', y = 'petal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.kdeplot(data = df_iris, x = 'sepal_length', y = 'sepal_width', hue='species')
# sns.scatterplot(data = df_iris, x = 'sepal_length', y = 'sepal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
#jointplot

# %%
sns.jointplot(data = df_iris, x = 'sepal_length', y = 'sepal_width', hue='species')

# %%
sns.jointplot(data = df_iris, x = 'sepal_length', y = 'sepal_width', hue='species',kind='kde')

# %%
sns.jointplot(data = df_iris, x = 'sepal_length', y = 'sepal_width',kind='hex')

# %%
sns.jointplot(data = df_iris, x = 'sepal_length', y = 'sepal_width',kind='reg')

# %%
# pip install cowsay
# Out:
# ...
#
# ...

# %%
import cowsay
cowsay.cow('Hello Hriday')
# Out:
#   ____________
# | Hello Hriday |
# ...
#             \
#              \
#                ^__^
#                (oo)\_______
#                (__)\       )\/\
#                    ||----w |
#                    ||     ||

# %%
cowsay.turtle('Hello Hriday')
# Out:
#   ____________
# | Hello Hriday |
# ...
#               \
#                \
#                 \
#                  \
#                                             ___-------___
#                                         _-~~             ~~-_
#                                      _-~                    /~-_
#                    /^\__/^\         /~  \                   /    \
#                  /|  O|| O|        /      \_______________/        \
#                 | |___||__|      /       /                \          \
#                 |          \    /      /                    \          \
#                 |   (_______) /______/                        \_________ \
#                 |         / /         \                      /            \
#                  \         \^\\         \                  /               \     /
#                    \         ||           \______________/      _-_       //\__//
#                      \       ||------_-~~-_ ------------- \ --/~   ~\    || __/
# ...

# %%
import IPython

# %%
# can play youtube video in jupyter
# IPython.display.YouTubeVideo('RdWqM8BvB3A') allow_autoplay= True

# %% [markdown]
# # machine learning

# %%
# machine learning : data science : science of understanding data 
# data : raw information/ fact

# %%
# past: prediction 
# supervised ML : guide
# unsupervised ML 
# reinforcement ML
#
